# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def extract_country(location):
    # Assuming the country is always the last part of the location string
    return location.split(',')[-1].strip()

def extract_city(location):
    # Assuming the city is the part before the last comma
    parts = location.split(',')
    return ', '.join(parts[:-1]).strip() if len(parts) > 1 else parts[0].strip()

def get_job_description(job_url):
    response = requests.get(job_url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        description_tag = soup.find('div', class_='wpjb-text')
        if description_tag:
            return description_tag.text.strip()
    return ""

def scrape_jobs(url):
    jobs_list = []
    while url:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            jobs = soup.find_all('div', class_='wpjb-grid-row')
            for job in jobs:
                title_tag = job.find('a', class_='wpjb-job_title wpjb-title')
                company_tag = job.find('span', class_='wpjb-sub wpjb-company_name')
                location_tag = job.find('span', class_='wpjb-glyphs wpjb-icon-location')
                type_tag = job.find('span', class_='wpjb-job_type wpjb-sub-title')

                if title_tag and company_tag and location_tag and type_tag:
                    title = title_tag.text.strip()
                    company = company_tag.text.strip()
                    locations = location_tag.text.strip().replace('/', ',').split(',')
                    job_type = type_tag.text.strip()
                    job_url = title_tag['href']
                    description = get_job_description(job_url)

                    country = extract_country(location_tag.text.strip())
                    for location in locations:
                        city = extract_city(location.strip())
                        job_details = {
                            "title": title,
                            "company": company,
                            "city": city,
                            "country": country,
                            "type": job_type,
                            "description": description
                        }
                        jobs_list.append(job_details)

            next_page_tag = soup.find('a', class_='next page-numbers')
            url = next_page_tag['href'] if next_page_tag else None
        else:
            break
    return jobs_list

start_url = 'https://womenindata.co.uk/diverse-data-jobs/'
jobs = scrape_jobs(start_url)

# Save to CSV
df = pd.DataFrame(jobs)

# %%
df.head(20)
# Out:
#                                             title      company  \
# 0   Principal - Online Safety Market Intelligence        Ofcom
# 1   Principal - Online Safety Market Intelligence        Ofcom
# 2   Principal - Online Safety Market Intelligence        Ofcom
# 3   Principal - Online Safety Market Intelligence        Ofcom
# 4                         Data Innovation Analyst           BP
# 5                         Data Innovation Analyst           BP
# 6                               Data Scientist II   LexisNexis
# 7                               Data Scientist II   LexisNexis
# 8                     Data Enabled Change Advisor  Bae Systems
# 9                     Data Enabled Change Advisor  Bae Systems
# 10                    Market Intelligence Analyst        Ofcom
# 11                    Market Intelligence Analyst        Ofcom
# 12                    Market Intelligence Analyst        Ofcom
# 13                    Market Intelligence Analyst        Ofcom
# 14                               Research Analyst        Ofcom
# 15                               Research Analyst        Ofcom
# 16                               Research Analyst        Ofcom
# 17                               Research Analyst        Ofcom
# 18                        Senior Research Manager        Ofcom
# 19                        Senior Research Manager        Ofcom
#
#               city         country       type  \
# 0           London  United Kingdom  Full-time
# 1       Manchester  United Kingdom  Full-time
# 2        Edinburgh  United Kingdom  Full-time
# 3   United Kingdom  United Kingdom  Full-time
# 4           London  United Kingdom  Full-time
# 5   United Kingdom  United Kingdom  Full-time
# 6           London  United Kingdom  Full-time
# 7   United Kingdom  United Kingdom  Full-time
# 8          Frimley  United Kingdom  Full-time
# 9   United Kingdom  United Kingdom  Full-time
# 10          London  United Kingdom  Full-time
# 11      Manchester  United Kingdom  Full-time
# 12       Edinburgh  United Kingdom  Full-time
# 13  United Kingdom  United Kingdom  Full-time
# 14          London  United Kingdom  Full-time
# 15      Manchester  United Kingdom  Full-time
# 16         Cardiff  United Kingdom  Full-time
# 17  United Kingdom  United Kingdom  Full-time
# 18          London  United Kingdom  Full-time
# 19      Manchester  United Kingdom  Full-time
#
#                                           description
# 0   Location: London, Manchester, Edinburgh\nClosi...
# 1   Location: London, Manchester, Edinburgh\nClosi...
# 2   Location: London, Manchester, Edinburgh\nClosi...
# 3   Location: London, Manchester, Edinburgh\nClosi...
# 4   Locations: United Kingdom - London\nTime type:...
# 5   Locations: United Kingdom - London\nTime type:...
# 6   Would you like to work with data?\nWould you l...
# 7   Would you like to work with data?\nWould you l...
# 8   Location: Frimley. We offer a range of hybrid ...
# 9   Location: Frimley. We offer a range of hybrid ...
# 10  Location: London, Manchester, Edinburgh\nClosi...
# 11  Location: London, Manchester, Edinburgh\nClosi...
# 12  Location: London, Manchester, Edinburgh\nClosi...
# 13  Location: London, Manchester, Edinburgh\nClosi...
# 14  Location: London, Manchester, Cardiff\nClosing...
# 15  Location: London, Manchester, Cardiff\nClosing...
# 16  Location: London, Manchester, Cardiff\nClosing...
# 17  Location: London, Manchester, Cardiff\nClosing...
# 18  Location: London, Manchester, Edinburgh\nClosi...
# 19  Location: London, Manchester, Edinburgh\nClosi...

# %%
#ex_df= pd.read_csv('jobs.csv')

# %%
df = df.loc[df.iloc[::-1].duplicated(subset='title', keep='first')[::-1] == True]

# %%
df.to_csv('jobs.csv', index=False)

# %%
keywords = [
    'Data Analysis', 'Data Visualization', 'SQL', 'Python', 'Machine Learning',
    'Statistical Analysis', 'Data Mining', 'Big Data', 'R Programming',
    'Data Warehousing', 'ETL (Extract, Transform, Load)', 'Data Cleaning',
    'Predictive Analytics', 'Business Intelligence', 'Data Governance',
    'Data Modeling', 'Hadoop', 'Tableau', 'Power BI', 'Data Architecture'
]

# %%
def find_keywords(description):
    found_keywords = [keyword for keyword in keywords if keyword.lower() in description.lower()]
    return ', '.join(found_keywords)

df['found_keywords'] = df['description'].apply(find_keywords)

# %%
df.head(20)
# Out:
#                                             title       company        city  \
# 0   Principal - Online Safety Market Intelligence         Ofcom      London
# 1   Principal - Online Safety Market Intelligence         Ofcom  Manchester
# 2   Principal - Online Safety Market Intelligence         Ofcom   Edinburgh
# 4                         Data Innovation Analyst            BP      London
# 6                               Data Scientist II    LexisNexis      London
# 8                     Data Enabled Change Advisor   Bae Systems     Frimley
# 10                    Market Intelligence Analyst         Ofcom      London
# 11                    Market Intelligence Analyst         Ofcom  Manchester
# 12                    Market Intelligence Analyst         Ofcom   Edinburgh
# 14                               Research Analyst         Ofcom      London
# 15                               Research Analyst         Ofcom  Manchester
# 16                               Research Analyst         Ofcom     Cardiff
# 18                        Senior Research Manager         Ofcom      London
# 19                        Senior Research Manager         Ofcom  Manchester
# 20                        Senior Research Manager         Ofcom   Edinburgh
# 22                             Economics Director         Ofcom      London
# 23                             Economics Director         Ofcom  Manchester
# 24                             Economics Director         Ofcom   Edinburgh
# 26                            Lead Data Scientist  Vanquis Bank      London
# 27                            Lead Data Scientist  Vanquis Bank    Bradford
#
#            country       type  \
# 0   United Kingdom  Full-time
# 1   United Kingdom  Full-time
# 2   United Kingdom  Full-time
# 4   United Kingdom  Full-time
# 6   United Kingdom  Full-time
# 8   United Kingdom  Full-time
# 10  United Kingdom  Full-time
# 11  United Kingdom  Full-time
# 12  United Kingdom  Full-time
# 14  United Kingdom  Full-time
# 15  United Kingdom  Full-time
# 16  United Kingdom  Full-time
# 18  United Kingdom  Full-time
# 19  United Kingdom  Full-time
# 20  United Kingdom  Full-time
# 22  United Kingdom  Full-time
# 23  United Kingdom  Full-time
# 24  United Kingdom  Full-time
# 26  United Kingdom  Full-time
# 27  United Kingdom  Full-time
#
#                                           description  \
# 0   Location: London, Manchester, Edinburgh\nClosi...
# 1   Location: London, Manchester, Edinburgh\nClosi...
# 2   Location: London, Manchester, Edinburgh\nClosi...
# 4   Locations: United Kingdom - London\nTime type:...
# 6   Would you like to work with data?\nWould you l...
# 8   Location: Frimley. We offer a range of hybrid ...
# 10  Location: London, Manchester, Edinburgh\nClosi...
# 11  Location: London, Manchester, Edinburgh\nClosi...
# 12  Location: London, Manchester, Edinburgh\nClosi...
# 14  Location: London, Manchester, Cardiff\nClosing...
# 15  Location: London, Manchester, Cardiff\nClosing...
# 16  Location: London, Manchester, Cardiff\nClosing...
# 18  Location: London, Manchester, Edinburgh\nClosi...
# 19  Location: London, Manchester, Edinburgh\nClosi...
# 20  Location: London, Manchester, Edinburgh\nClosi...
# 22  Closing Date: 03/06/2024\nGroup: Economics and...
# 23  Closing Date: 03/06/2024\nGroup: Economics and...
# 24  Closing Date: 03/06/2024\nGroup: Economics and...
# 26  Location: London, Chatham, Bradford, Petersfie...
# 27  Location: London, Chatham, Bradford, Petersfie...
#
#                                        found_keywords
# 0                                       Data Analysis
# 1                                       Data Analysis
# 2                                       Data Analysis
# 4    SQL, Machine Learning, Data Governance, Power BI
# 6                          Data Analysis, SQL, Python
# 8                                    Machine Learning
# 10                    Data Analysis, Python, Power BI
# 11                    Data Analysis, Python, Power BI
# 12                    Data Analysis, Python, Power BI
# 14
# 15
# 16
# 18
# 19
# 20
# 22
# 23
# 24
# 26  SQL, Python, Machine Learning, Statistical Ana...
# 27  SQL, Python, Machine Learning, Statistical Ana...
